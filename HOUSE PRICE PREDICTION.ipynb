# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('kc_house_data.csv.zip')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
print('number of rows:', df.shape[0])
print('number of columns:', df.shape[1])
# Out:
# number of rows: 21613
# number of columns: 21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.describe(include = "all")
# Out:
#                   id             date         price      bedrooms  \
# count   2.161300e+04            21613  2.161300e+04  21613.000000
# unique           NaN              372           NaN           NaN
# top              NaN  20140623T000000           NaN           NaN
# freq             NaN              142           NaN           NaN
# mean    4.580302e+09              NaN  5.400881e+05      3.370842
# std     2.876566e+09              NaN  3.671272e+05      0.930062
# min     1.000102e+06              NaN  7.500000e+04      0.000000
# 25%     2.123049e+09              NaN  3.219500e+05      3.000000
# 50%     3.904930e+09              NaN  4.500000e+05      3.000000
# 75%     7.308900e+09              NaN  6.450000e+05      4.000000
# max     9.900000e+09              NaN  7.700000e+06     33.000000
#
#            bathrooms   sqft_living      sqft_lot        floors    waterfront  \
# count   21613.000000  21613.000000  2.161300e+04  21613.000000  21613.000000
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df['date']
# Out:
# 0        20141013T000000
# 1        20141209T000000
# 2        20150225T000000
# 3        20141209T000000
# 4        20150218T000000
#               ...
# 21608    20140521T000000
# 21609    20150223T000000
# 21610    20140623T000000
# 21611    20150116T000000
# 21612    20141015T000000
# Name: date, Length: 21613, dtype: object

# %%
df1=df.drop('date',axis=1)

# %%
df1
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
data=df1.drop('id',axis=1)

# %%
data
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
data.shape
# Out:
# (21613, 19)

# %%
data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS FOR COLUMNS

# %%
df['price'].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(data['price'],kde=True)
plt.title('histplot for price')
plt.subplot(1,2,2)
sns.boxplot(data['price'])
plt.title('boxplot for price')
# Out:
# Text(0.5, 1.0, 'boxplot for price')

# %%
Q1=data['price'].quantile(0.25)
Q3=data['price'].quantile(0.75)
IQR=Q3-Q1
lower=Q1-1.5*IQR
upper=Q3+1.5*IQR
filtered=data[(df.price>=lower)&(df.price<=upper)]
data=filtered

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(data['price'],kde=True)
plt.title('histplot for price')
plt.subplot(1,2,2)
sns.boxplot(data=data,x='price')
plt.title('boxplot for price')
# Out:
# Text(0.5, 1.0, 'boxplot for price')

# %%
data['bedrooms']
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 20467, dtype: int64

# %%
data['bedrooms'].describe()
# Out:
# count    20467.000000
# mean         3.329750
# std          0.912885
# min          0.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         33.000000
# Name: bedrooms, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(data=data,x='bedrooms',kde=True)
plt.title('distplot for bedrooms')
plt.subplot(1,2,2)
sns.boxplot(data=data,x='bedrooms')
plt.title('boxplot for bedrooms')
# Out:
# Text(0.5, 1.0, 'boxplot for bedrooms')

# %%
Q1=df['bedrooms'].quantile(0.25)
Q3=df['bedrooms'].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR

df_filtered=df[(df.bedrooms>=lower) & (df.bedrooms<=upper)]
df=df_filtered

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['bedrooms'],kde=True)
plt.title('distplot for bedrooms')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='bedrooms')
plt.title('boxplot for bedrooms')
# Out:
# Text(0.5, 1.0, 'boxplot for bedrooms')

# %%
df['bathrooms'].describe()
# Out:
# count    21067.000000
# mean         2.108618
# std          0.746090
# min          0.500000
# 25%          1.750000
# 50%          2.250000
# 75%          2.500000
# max          6.750000
# Name: bathrooms, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['bathrooms'],kde=True)
plt.title('distplot for bathrooms')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='bathrooms')
plt.title('boxplot for bathrooms')
# Out:
# Text(0.5, 1.0, 'boxplot for bathrooms')

# %%
Q1=df['bathrooms'].quantile(0.25)
Q3=df['bathrooms'].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR

df_filtered=df[(df.bathrooms>=lower)&(df.bathrooms<=upper)]
df=df_filtered

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['bathrooms'],kde=True)
plt.title('distplot for bathrooms')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='bathrooms')
plt.title('boxplot for bathrooms')
# Out:
# Text(0.5, 1.0, 'boxplot for bathrooms')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df['sqft_living'].describe()
# Out:
# count    20606.00000
# mean      2019.30991
# std        806.92837
# min        440.00000
# 25%       1420.00000
# 50%       1890.00000
# 75%       2480.00000
# max       7420.00000
# Name: sqft_living, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['sqft_living'],kde=True)
plt.title('distplot for sqft_living')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='sqft_living')
plt.title('boxplot for sqft_living')
# Out:
# Text(0.5, 1.0, 'boxplot for sqft_living')

# %%
Q1=df['sqft_living'].quantile(0.25)
Q3=df['sqft_living'].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR

df_filtered=df[(df.sqft_living>=lower)&(df.sqft_living<=upper)]
df=df_filtered

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['sqft_living'],kde=True)
plt.title('distplot for sqft_living')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='sqft_living')
plt.title('boxplot for sqft_living')
# Out:
# Text(0.5, 1.0, 'boxplot for sqft_living')

# %%
df['sqft_lot'].describe()
# Out:
# count    2.022900e+04
# mean     1.416508e+04
# std      3.933426e+04
# min      5.200000e+02
# 25%      5.000000e+03
# 50%      7.500000e+03
# 75%      1.030000e+04
# max      1.651359e+06
# Name: sqft_lot, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['sqft_lot'],kde=True)
plt.title('distplot for sqft_lot')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='sqft_lot')
plt.title('boxplot for sqft_lot')
# Out:
# Text(0.5, 1.0, 'boxplot for sqft_lot')

# %%
Q1=df['sqft_lot'].quantile(0.25)
Q3=df['sqft_lot'].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR

df_filtered=df[(df.sqft_lot>=lower)&(df.sqft_lot<=upper)]
df=df_filtered

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['sqft_lot'],kde=True)
plt.title('distplot for sqft_lot')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='sqft_lot')
plt.title('boxplot for sqft_lot')
# Out:
# Text(0.5, 1.0, 'boxplot for sqft_lot')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df['floors'].describe()
# Out:
# count    18081.000000
# mean         1.480117
# std          0.544284
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          3.500000
# Name: floors, dtype: float64

# %%
sns.boxplot(data=df,x='floors')
# Out:
# <Axes: xlabel='floors'>

# %%
df['waterfront'].describe()
# Out:
# count    18081.000000
# mean         0.003484
# std          0.058927
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: waterfront, dtype: float64

# %%
sns.histplot(data=df,x='waterfront')
# Out:
# <Axes: xlabel='waterfront', ylabel='Count'>

# %%
df['view'].describe()
# Out:
# count    18081.000000
# mean         0.177977
# std          0.655359
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          4.000000
# Name: view, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['view'],kde=True)
plt.title('distplot for view')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='view')
plt.title('boxplot for view')
# Out:
# Text(0.5, 1.0, 'boxplot for view')

# %%
Q1=df['view'].quantile(0.25)
Q3=df['view'].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR

df_filtered=df[(df.view>=lower)&(df.view<=upper)]
df=df_filtered

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['view'],kde=True)
plt.title('distplot for view')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='view')
plt.title('boxplot for view')
# Out:
# Text(0.5, 1.0, 'boxplot for view')

# %%
df['grade'].describe()
# Out:
# count    16649.000000
# mean         7.456123
# std          0.962106
# min          4.000000
# 25%          7.000000
# 50%          7.000000
# 75%          8.000000
# max         12.000000
# Name: grade, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['grade'],kde=True)
plt.title('distplot for grade')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='grade')
plt.title('boxplot for grade')
# Out:
# Text(0.5, 1.0, 'boxplot for grade')

# %%
Q1=df['grade'].quantile(0.25)
Q3=df['grade'].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.25*IQR
upper=Q3+1.25*IQR

df_filtered=df[(df.grade>=lower)&(df.grade<=upper)]
df=df_filtered

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['grade'],kde=True)
plt.title('distplot for grade')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='grade')
plt.title('boxplot for grade')
# Out:
# Text(0.5, 1.0, 'boxplot for grade')

# %%
df['sqft_above'].describe()
# Out:
# count    15973.000000
# mean      1600.522382
# std        613.786074
# min        480.000000
# 25%       1150.000000
# 50%       1440.000000
# 75%       1930.000000
# max       4030.000000
# Name: sqft_above, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['sqft_above'],kde=True)
plt.title('distplot for sqft_above')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='sqft_above')
plt.title('boxplot for sqft_above')
# Out:
# Text(0.5, 1.0, 'boxplot for sqft_above')

# %%
Q1=df['sqft_above'].quantile(0.25)
Q3=df['sqft_above'].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.25*IQR
upper=Q3+1.25*IQR

df_filtered=df[(df.sqft_above>=lower)&(df.sqft_above<=upper)]
df=df_filtered

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['sqft_above'],kde=True)
plt.title('distplot for sqft_above')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='sqft_above')
plt.title('boxplot for sqft_above')
# Out:
# Text(0.5, 1.0, 'boxplot for sqft_above')

# %%
df['sqft_basement'].describe()
# Out:
# count    15282.000000
# mean       249.530690
# std        374.270516
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        500.000000
# max       2000.000000
# Name: sqft_basement, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['sqft_basement'],kde=True)
plt.title('distplot for sqft_basement')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='sqft_basement')
plt.title('boxplot for sqft_basement')
# Out:
# Text(0.5, 1.0, 'boxplot for sqft_basement')

# %%
plt.figure(figsize=(12,5))
sns.boxplot(data=df,x='sqft_basement')
plt.title('boxplot')
# Out:
# Text(0.5, 1.0, 'boxplot')

# %%
Q1=df['sqft_basement'].quantile(0.25)
Q3=df['sqft_basement'].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR

df_filtered=df[(df.sqft_basement>=lower) & (df.sqft_basement<=upper)]
df=df_filtered

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['sqft_basement'],kde=True)
plt.title('distplot for sqft_basement')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='sqft_basement')
plt.title('boxplot for sqft_basement')
# Out:
# Text(0.5, 1.0, 'boxplot for sqft_basement')

# %%
df['long'].describe()
# Out:
# count    15047.000000
# mean      -122.231577
# std          0.130492
# min       -122.509000
# 25%       -122.337000
# 50%       -122.273000
# 75%       -122.159000
# max       -121.319000
# Name: long, dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['long'],kde=True)
plt.title('distplot for long')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='long')
plt.title('boxplot for long')
# Out:
# Text(0.5, 1.0, 'boxplot for long')

# %%
Q1=df['long'].quantile(0.25)
Q3=df['long'].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR

df_filtered=df[(df.long>=lower) & (df.long<=upper)]
df=df_filtered

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['long'],kde=True)
plt.title('distplot for long')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='long')
plt.title('boxplot for long')
# Out:
# Text(0.5, 1.0, 'boxplot for long')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df['sqft_lot15'].describe()
# Out:
# count     14722.000000
# mean       7005.586062
# std        4251.713532
# min         651.000000
# 25%        4700.000000
# 50%        7200.000000
# 75%        8700.000000
# max      196591.000000
# Name: sqft_lot15, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.histplot(df['sqft_lot15'],kde=True)
plt.title('distplot for sqft_lot15')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='sqft_lot15')
plt.title('boxplot for sqft_lot15')
# Out:
# Text(0.5, 1.0, 'boxplot for sqft_lot15')

# %%
Q1=df['sqft_lot15'].quantile(0.25)
Q3=df['sqft_lot15'].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR

df_filtered=df[(df.sqft_lot15>=lower)&(df.sqft_lot15<=upper)]
df=df_filtered

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.histplot(df['sqft_lot15'],kde=True)
plt.title('distplot for sqft_lot15')
plt.subplot(1,2,2)
sns.boxplot(data=df,x='sqft_lot15')
plt.title('boxplot for sqft_lot15')
# Out:
# Text(0.5, 1.0, 'boxplot for sqft_lot15')

# %%
categorical_columns=df.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['date'], dtype='object')

# %%
numerical_columns=df.select_dtypes(include=['number']).columns
numerical_columns
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.histplot(data=df,x='bedrooms',color='g')
# Out:
# <Axes: xlabel='bedrooms', ylabel='Count'>

# %%
sns.kdeplot(data=df,x='price',fill=True)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.histplot(df,x='price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.scatterplot(df,x='bedrooms',y='price')
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df.head(3)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# ...

# %%
df.head(3)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# ...

# %%
sns.barplot(df,x='floors',y='sqft_lot',hue='grade')
# Out:
# <Axes: xlabel='floors', ylabel='sqft_lot'>

# %%
sns.jointplot(df,x='sqft_above',y='sqft_basement')

# %%
correlation=['sqft_above','sqft_basement','sqft_lot15']
sns.pairplot(df[correlation],diag_kind='kde')

# %%
correlation=['sqft_living','sqft_lot','sqft_living15','sqft_lot15']
sns.pairplot(df[correlation],diag_kind='kde')

# %% [markdown]
# # MACHINE LEARNING ALGORITHMS

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df=df.drop('date',axis=1)

# %%
df
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
df=df.drop('id',axis=1)

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
df.head(3)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# 0    98178  47.5112 -122.257           1340        5650
# 1    98125  47.7210 -122.319           1690        7639
# 2    98028  47.7379 -122.233           2720        8062

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
x
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00         1180      5650     1.0           0     0
# 1             3       2.25         2570      7242     2.0           0     0
# 2             2       1.00          770     10000     1.0           0     0
# 3             4       3.00         1960      5000     1.0           0     0
# 4             3       2.00         1680      8080     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3       2.50         1530      1131     3.0           0     0
# 21609         4       2.50         2310      5813     2.0           0     0
# 21610         2       0.75         1020      1350     2.0           0     0
# 21611         3       2.50         1600      2388     2.0           0     0
# 21612         2       0.75         1020      1076     2.0           0     0
#
# ...

# %%
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 14411, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
x_train.shape,x_test.shape
# Out:
# ((11528, 18), (2883, 18))

# %%
y_train.shape,y_test.shape
# Out:
# ((11528,), (2883,))

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_scaled=sc.fit_transform(x_train)
x_test_scaled=sc.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-1.60780161, -0.29193608, -0.12539632, ...,  1.40433623,
#          1.38333782,  0.38648467],
#        [ 1.01900352,  0.86656277,  2.05859387, ...,  0.98542598,
#          2.47769497, -0.53755285],
#        [-0.29439905, -0.29193608, -0.64454153, ..., -0.82985177,
#          0.13877478,  1.04540641],
#        ...,
#        [ 1.01900352,  0.48039648,  1.3067284 , ...,  1.24724489,
#          1.9197874 ,  1.08232572],
#        [-0.29439905,  0.86656277, -0.0895932 , ..., -1.18767094,
#         -0.33330085,  0.58795861],
#        [-0.29439905, -0.29193608, -0.12539632, ..., -0.42839611,
#         -0.140179  , -0.92186526]])

# %%
x_train
# Out:
# array([[-1.60780161, -0.29193608, -0.12539632, ...,  1.40433623,
#          1.38333782,  0.38648467],
#        [ 1.01900352,  0.86656277,  2.05859387, ...,  0.98542598,
#          2.47769497, -0.53755285],
#        [-0.29439905, -0.29193608, -0.64454153, ..., -0.82985177,
#          0.13877478,  1.04540641],
#        ...,
#        [ 1.01900352,  0.48039648,  1.3067284 , ...,  1.24724489,
#          1.9197874 ,  1.08232572],
#        [-0.29439905,  0.86656277, -0.0895932 , ..., -1.18767094,
#         -0.33330085,  0.58795861],
#        [-0.29439905, -0.29193608, -0.12539632, ..., -0.42839611,
#         -0.140179  , -0.92186526]])

# %%
plt.subplots(figsize=(25, 6))
plt.subplot(1, 2, 1)
sns.boxplot(data=x_train)
plt.title('X_train Before Scaling')
plt.subplot(1, 2, 2)
sns.boxplot(data=x_train_scaled)
plt.title('X_train After Scaling')
# Out:
# Text(0.5, 1.0, 'X_train After Scaling')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
LR=LinearRegression()
LR.fit(x_train_scaled,y_train)
y_pred=LR.predict(x_test_scaled)

mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
score=r2_score(y_test,y_pred) 

print('The mean absolute error is :',mae)
print('The mean squared error is :',mse)
print('The r2 score is:', score)
# Out:
# The mean absolute error is : 86953.84805257226
# The mean squared error is : 14884085276.458704
# The r2 score is: 0.6090744535396329

# %%
plt.scatter(y_test,y_pred)

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = LR, X = x_train_scaled, y = y_train, cv = 5)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
# Out:
# Accuracy: 63.51 %

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
rndf=RandomForestRegressor()
rndf.fit(x_train_scaled,y_train)
y_pred=rndf.predict(x_test_scaled)

mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
score=r2_score(y_test,y_pred)

print('The mean absolute error is :',mae)
print('The mean squared error is :',mse)
print('The r2 score is:', score)
# Out:
# The mean absolute error is : 48996.90737403169
# The mean squared error is : 5638463248.133509
# The r2 score is: 0.8519076392313087

# %%
plt.scatter(y_test,y_pred)

# %%
from sklearn.model_selection import cross_val_score
accuracy=cross_val_score(estimator=rndf,X=x_train_scaled,y=y_train,cv=5)
print('accuracy: {:.2f} %'.format (accuracies.mean()*100))
# Out:
# accuracy: 63.51 %

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
DTR=DecisionTreeRegressor()
DTR.fit(x_train_scaled,y_train)
y_pred=DTR.predict(x_test_scaled)

mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
score=r2_score(y_test,y_pred)

print('the mean absolute error is :',mae)
print('the mean squared error is :',mse)
print('the r2 score is :',score)
# Out:
# the mean absolute error is : 68600.60822060354
# the mean squared error is : 10726250793.174385
# the r2 score is : 0.7182785925430883

# %%
plt.scatter(y_test,y_pred)

# %%
from sklearn.model_selection import cross_val_score
accuracy=cross_val_score(estimator=DTR,X=x_train_scaled,y=y_train,cv=5)
print('accuracy: {:.2f} %'.format (accuracies.mean()*100))
# Out:
# accuracy: 63.51 %

# %%
import pickle # To save model for future use

from sklearn.ensemble import RandomForestRegressor

# Initializing the Random Forest Regressor
model = RandomForestRegressor(n_estimators=100, random_state=42)

# Training the model on the training set
model.fit(x_train_scaled, y_train)

# Making predictions on the testing set
y_pred = model.predict(x_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)

print("Mean absolute error", mae)
print("R2 Score", score)

plt.scatter(y_test,y_pred)

pickle.dump(model , open('house_price.pk1' , 'wb'))
# Out:
# Mean absolute error 48847.27118765175
# R2 Score 0.8535701320037044

# %%
import pickle

house_price_model = pickle.load(open('house_price.pk1' , 'rb'))

house_price_model_accuracy = house_price_model.score(x_test_scaled, y_test)

print("House Price Model Accuracy:" , house_price_model_accuracy * 100 , "%")
# Out:
# House Price Model Accuracy: 85.35701320037043 %
